# %% [markdown]
# ## **Média simples** \begin{align}
#         \mathbf{𝞵}  &= \sum_{i=1}^n x_i &= x_1 + x_2 + x_3 + ... + x_n.
#     \end{align}

# %%
x1 = 10
x2 = 9
x3 = 10
x4 = 7.5
x5 = 9.9

media = (x1 + x2 + x3 + x4 + x5)/5
print("Média: ", media)
# Out:
# Média:  9.28

# %% [markdown]
# # **Operações Básicas**

# %%
2+2
# Out:
# 4

# %%
5*4
# Out:
# 20

# %%
10 - 1
# Out:
# 9

# %%
4 + 7 * 2
# Out:
# 18

# %%
(4 + 7) * 2
# Out:
# 22

# %%
4**2
# Out:
# 16

# %% [markdown]
# # **Desvio Padrão** \begin{align}
#         \mathbf{\sigma}  &= \sqrt{\frac{\sum_{i=1}^n (x_i - 𝞵)^2}{n}}
#     \end{align}

# %%
x1 = 10
x2 = 9
x3 = 10
x4 = 7.5
x5 = 9.9

media = (x1 + x2 + x3 + x4 + x5)/5

somatorio = (x1 - media)**2 + (x2 - media)**2 + (x3 - media)**2 + (x4 - media)**2 + (x5 - media)**2
desvio_padrao = (somatorio/5)**(1/2)

print("Desvio padrão: ", desvio_padrao)
# Out:
# Desvio padrão:  0.9662297863344931

# %%
idade = 80
doenca = input("Tem doença infectocontagiosa? Digite sim ou não ")
COVID = input("Tem COVID? Digite sim ou não ")

sim = ["SIM", "S", "YES"]
nao  = ["NÃO", "NAO", "NO", "N"]

if idade >= 60 and doenca.upper() in sim:  #SIM
  print("Paciente com prioridade e direcionado à sala reservada")
  if COVID == "SIM":
    print("Urgente!!!")
elif idade >= 60 and doenca.upper() in nao:
  print("Paciente com prioridade")
elif idade < 60 and doenca.upper() in sim:
  print("Paciente direcionado à sala reservada")
elif idade < 60 and doenca.upper() in nao :
  print("senta aí e espera")
# Out:
# Tem doença infectocontagiosa? Digite sim ou não sim
# Tem COVID? Digite sim ou não não
# Paciente com prioridade e direcionado à sala reservada

# %% [markdown]
# # **Aplicando a biblioteca matemática Numpy**

# %%
import numpy as np

# Dados de exemplo (valores de uma variável)
notas = [10, 9, 10, 7.5, 9.9]

dados = np.array(notas)

# Cálculo da média
media = np.mean(dados)
print("Média:", media)

# Cálculo do desvio padrão
desvio_padrao = np.std(dados)
print("Desvio Padrão:", desvio_padrao)
# Out:
# Média: 9.28
# Desvio Padrão: 0.9662297863344931

# %%
x = [2, 3, 4, 5]
print("Tipo da variável x: ", type(x))

x = np.array(x)
print("Tipo da variável x: ", type(x))
# Out:
# Tipo da variável x:  <class 'list'>
# Tipo da variável x:  <class 'numpy.ndarray'>

# %%
x[-1]
# Out:
# 5

# %% [markdown]
# # **Exercício 1)**
# **A empresa "A" possui 10 funcionários, cujos cargos e salários são:** \\
#  \\
#
# *   3 Diretores: 15000 (cada)
# *   5 programadores: 4000 (cada)
# *   1 Analista de marketing: 2500
# *   1 Auxiliar de serviços gerais: 1700 \\
#
# **A empresa "B" possui 5 funcionários, cujos cargos e salários são:** \\
#
# *   1 Diretor: 4000
# *   1 programador: 3500 (cada)
# *   1 Analista de marketing: 3000
# *   2 Auxiliares de serviços gerais: 2000 \\
#
# **Qual a média salarial e desvio padrão de cada empresa?** \\

# %%
salarios_a = np.array([15000, 15000, 15000, 4000, 4000, 4000, 4000, 4000, 2500, 1700])
media_a = np.mean(salarios_a)
desvio_a = np.std(salarios_a)
print("Média da empresa A: ", media_a)
print("Desvio padrão da empresa A: ", desvio_a, "\n")

salarios_b = np.array([4000,3500,3000,2000,2000])
media_b = np.mean(salarios_b)
desvio_b = np.std(salarios_b)
print("Média da empresa B: ", media_b)
print("Desvio padrão da empresa B: ", desvio_b)
# Out:
# Média da empresa A:  6920.0
# Desvio padrão da empresa A:  5341.123477321977
#
# Média da empresa B:  2900.0
# Desvio padrão da empresa B:  800.0

# %% [markdown]
# ## **Plotando gráficos**

# %% [markdown]
# ***`Gráfico de linhas`***

# %%
import matplotlib.pyplot as plt

# Dados de exemplo (valores ao longo do tempo)
anos = [2017, 2018, 2019, 2020, 2021, 2022, 2023]
salario = [3400, 5000, 6000, 7000, 6500, 9000, 15000]
salario2 = [1000, 2500, 4500, 6000, 4400, 4800, 9000]

ano_projecao = [2023,2024,2025,2026,2027,2028]
projecao = [9000, 10000, 11000, 12000, 13000, 14000]

plt.plot(anos, salario, marker='x', color='red')
plt.plot(anos, salario2, '-g^')
plt.plot(ano_projecao, projecao, ":bs")
plt.legend( ['Salário do Diretor', 'Salário do Gerente', 'Salário projetado do Gerente'] )

plt.title("Salário médio Anual")
plt.xlabel("Ano")
plt.ylabel("Salário (R$)")
plt.grid(True)
plt.show()

# %% [markdown]
# ***`Gráfico de colunas`***

# %%
# Dados de exemplo (valores de categorias)
categorias = ['A', 'B', 'C', 'D']
valores = [30, 50, 20, 40]
valores2 =  [20, 20, 20, 20]

plt.bar(categorias, valores, color='pink')
plt.bar(categorias, valores2, color='black')
plt.title("Distribuição por Categoria")
plt.xlabel("Categoria")
plt.ylabel("Valores")
plt.legend(["2010", "2011"])
plt.show()

# %%
x = ["João", "Maria", "Carlos Eduardo"]
y = [   300,   600,        900        ]
y2 =[   100,   500,        300        ]

plt.bar(x, y)
plt.bar(x, y2)
plt.title("Pontuação final do fliperama")
plt.xlabel("Jogadores")
plt.ylabel("Pontos")
plt.legend(['2022', '2023'])
plt.show()

# %% [markdown]
# # **Exercício 2)**
# Uma faculdade tirou a média das turmas S e R. A turma S teve as seguintes médias nos últimos 4 anos: 7.9, 8.0, 8.3 e 9.3. Já a turma R teve as seguintes médias: 5.0, 9.0, 9.1 e 9.7. Crie um gráfico de linhas e um de barras que demonstra a evolução das médias dos alunos ao longo dos anos

# %%
#gráfico de linhas
anos = ['2020', '2021', '2022', '2023']
turma_s = [7.9, 8.0, 8.3, 9.3]
turma_r = [5.0, 9.0, 9.1 , 9.7]

#plt.plot(anos, turma_s, '-bo')
plt.plot(anos, turma_s, color='red', marker='o' )
plt.plot(anos, turma_r, '-gx')
plt.title("Evolução das médias das turmas S e R ao longo de 4 anos")
plt.xlabel("Ano")
plt.ylabel("Média de nota")
plt.legend( ['Turma S', 'Turma R'] )
plt.grid(True)
plt.show()

# %%
#gráfico de colunas

anos = ['2020', '2021', '2022', '2023']
turma_s = [7.9, 8.0, 8.3, 9.3]
turma_r = [5.0, 9.0, 9.1 , 9.7]

plt.bar(anos, turma_r, color='blue')
plt.bar(anos, turma_s, color='red' )

plt.title("Evolução das médias das turmas S e R ao longo de 4 anos")
plt.xlabel("Ano")
plt.ylabel("Média de nota")
plt.legend( ['Turma R', 'Turma S'] )
plt.show()

# %% [markdown]
# # **Dataframes**

# %%
# Criando um DataFrame a partir de um dicionário
data = {
    'Nome': ['João', 'Maria', 'Ana', 'Pedro', 'Marcos', 'Raquel', 'Alberto', 'Ana'],
    'Idade': [15, 30, 28, 22, 13, 12, 47, 50],
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Brasília','Brasília', 'São Paulo', 'Manaus', 'Rio Branco']
}

df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# DataFrame:
#       Nome  Idade          Cidade
# 0     João     15       São Paulo
# 1    Maria     30  Rio de Janeiro
# 2      Ana     28  Belo Horizonte
# 3    Pedro     22        Brasília
# 4   Marcos     13        Brasília
# 5   Raquel     12       São Paulo
# 6  Alberto     47          Manaus
# 7      Ana     50      Rio Branco

# %% [markdown]
# **Imprimindo o dataframe sem print**

# %%
df
# Out:
#       Nome  Idade          Cidade
# 0     João     15       São Paulo
# 1    Maria     30  Rio de Janeiro
# 2      Ana     28  Belo Horizonte
# 3    Pedro     22        Brasília
# 4   Marcos     13        Brasília
# 5   Raquel     12       São Paulo
# 6  Alberto     47          Manaus
# 7      Ana     50      Rio Branco

# %% [markdown]
# **Imprimindo apenas as duas primeiras linhas**

# %%
df.head(2)
# Out:
#     Nome  Idade          Cidade
# 0   João     15       São Paulo
# 1  Maria     30  Rio de Janeiro

# %% [markdown]
# **Imprimindo as duas últimas linhas**

# %%
df.tail(2)
# Out:
#       Nome  Idade      Cidade
# 6  Alberto     47      Manaus
# 7      Ana     50  Rio Branco

# %% [markdown]
# **Imprimindo apenas a coluna nome**

# %%
# Acessando colunas do DataFrame
print("\nColuna 'Nome':\n")
df['Nome']
# Out:
# Coluna 'Nome':
# 0       João
# 1      Maria
# 2        Ana
# 3      Pedro
# 4     Marcos
# 5     Raquel
# 6    Alberto
# 7        Ana
# Name: Nome, dtype: object

# %% [markdown]
# **Aplicando um filtro por idade**

# %%
# Filtrando linhas com base em uma condição
adultos = df[df['Idade'] >= 18]
print("\nPessoas com mais de 18 anos:")
print(adultos)
# Out:
# Pessoas com mais de 18 anos:
#       Nome  Idade          Cidade
# 0     João     25       São Paulo
# 1    Maria     30  Rio de Janeiro
# 2      Ana     28  Belo Horizonte
# 3    Pedro     22        Brasília
# 6  Alberto     47          Manaus
# 7      Ana     50      Rio Branco

# %% [markdown]
# **Aplicando um filtro por cidade**

# %%
sp = df[ df['Cidade'] == 'São Paulo']
sp
# Out:
#      Nome  Idade     Cidade
# 0    João     25  São Paulo
# 5  Raquel     12  São Paulo

# %% [markdown]
# **Calculando a média e desvio padrão da idade**

# %%
idade_media = df['Idade'].mean()
idade_media
# Out:
# 28.375

# %%
idade_desvio = df['Idade'].std()
idade_desvio
# Out:
# 14.00956306038333

# %% [markdown]
# **Aplicando filtros por várias cidades**

# %%
cidades_selecionadas = ['Manaus', 'Rio Branco']
cidade = df[ df['Cidade'].isin(cidades_selecionadas)]
cidade
# Out:
#       Nome  Idade      Cidade
# 6  Alberto     47      Manaus
# 7      Ana     50  Rio Branco

# %% [markdown]
# **Aplicando múltiplos filtros por cidades e idade**

# %%
cidades_selecionadas = ['São Paulo', 'Brasília']
cidade = df[ (df['Cidade'].isin(cidades_selecionadas))  & (df['Idade'] >= 18)]
cidade
# Out:
#     Nome  Idade     Cidade
# 0   João     25  São Paulo
# 3  Pedro     22   Brasília

# %% [markdown]
# # Tópicos extras

# %%
import seaborn as sns

# Dados de exemplo (amostra de uma distribuição)
dados_amostra = np.random.normal(0, 1, 1000)

sns.kdeplot(dados_amostra, shade=True)
plt.title("Distribuição de Densidade")
plt.xlabel("Valores")
plt.ylabel("Densidade")
plt.show()
# Out:
# <ipython-input-13-aa5238e4e0cd>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dados_amostra, shade=True)

# %%
# Dados de exemplo (valores de diferentes grupos)
grupo1 = np.random.normal(50, 10, 100)
grupo2 = np.random.normal(70, 15, 100)
grupo3 = np.random.normal(40, 5, 100)

dados = [grupo1, grupo2, grupo3]

plt.boxplot(dados)
plt.title("Boxplot de Grupos")
plt.xticks([1, 2, 3], ['Grupo 1', 'Grupo 2', 'Grupo 3'])
plt.ylabel("Valores")
plt.show()

# %%
import pandas as pd

# Criando uma Series a partir de uma lista
notas = pd.Series([8.5, 7.2, 9.0, 6.8, 8.9])
print("Notas:")
print(notas)

# Acessando elementos da Series
print("\nPrimeira nota:", notas[0])
print("Média das notas:", notas.mean())

# Indexando a Series com rótulos
notas = pd.Series([8.5, 7.2, 9.0, 6.8, 8.9], index=['Aluno1', 'Aluno2', 'Aluno3', 'Aluno4', 'Aluno5'])
print("\nNotas com rótulos:")
print(notas)
# Out:
# Notas:
# 0    8.5
# 1    7.2
# 2    9.0
# 3    6.8
# 4    8.9
# dtype: float64
#
# Primeira nota: 8.5
# Média das notas: 8.08
#
# Notas com rótulos:
# Aluno1    8.5
# Aluno2    7.2
# Aluno3    9.0
# Aluno4    6.8
# Aluno5    8.9
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Dados dos preços de abertura e fechamento da ação em um período de 3 dias
preco_abertura = [10, 12, 13]
preco_fechamento = [12, 11.5, 22]

# Calcular variação percentual diária
variacao_percentual = [(f - a) / a for a, f in zip(preco_abertura, preco_fechamento)]

# Criar um boxplot das variações percentuais
plt.boxplot(variacao_percentual, vert=False)

# Adicionar título e rótulos dos eixos
plt.title('Variação Percentual Diária da Ação')
plt.xlabel('Variação Percentual')

# Exibir o gráfico
plt.show()

# %%
import pandas as pd

# Criar um DataFrame de exemplo com muitas linhas
data = {'coluna1': range(0, 1000, 2),
        'coluna2': range(0, 2000, 4)}
df = pd.DataFrame(data)

# Definir o número máximo de linhas para None (exibir todas as linhas)
pd.set_option('display.max_rows', None)

# Imprimir o DataFrame completo
df
# Out:
#      coluna1  coluna2
# 0          0        0
# 1          2        4
# 2          4        8
# 3          6       12
# 4          8       16
# 5         10       20
# 6         12       24
# 7         14       28
# 8         16       32
# 9         18       36
# 10        20       40
# 11        22       44
# 12        24       48
# 13        26       52
# 14        28       56
# 15        30       60
# 16        32       64
# 17        34       68
# 18        36       72
# 19        38       76
# 20        40       80
# 21        42       84
# 22        44       88
# 23        46       92
# 24        48       96
# 25        50      100
# 26        52      104
# 27        54      108
# 28        56      112
# 29        58      116
# 30        60      120
# 31        62      124
# 32        64      128
# 33        66      132
# 34        68      136
# 35        70      140
# 36        72      144
# 37        74      148
# 38        76      152
# 39        78      156
# ...

# %%
import matplotlib.pyplot as plt

# Dados das notas dos alunos A e B em cada semestre
semestres = ['1º Semestre', '2º Semestre', '3º Semestre', '4º Semestre']
notas_aluno_a = [10, 9, 10, 8]
notas_aluno_b = [8, 8, 8, 9]

# Posições no eixo x para cada grupo
x = range(len(semestres))

# Criar o gráfico de barras
plt.bar(x, notas_aluno_a, width=0.4, label='Aluno A')
plt.bar([i + 0.4 for i in x], notas_aluno_b, width=0.4, label='Aluno B')

# Configurar rótulos e legendas
plt.xlabel('Semestres')
plt.ylabel('Notas')
plt.title('Notas dos Alunos por Semestre')
plt.xticks([i + 0.2 for i in x], semestres)
plt.legend()

# Exibir o gráfico
plt.show()
